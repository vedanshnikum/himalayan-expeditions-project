# %% [markdown]
# # References and Dictionary
#
# ## Dictionary
# * Tells you what each data is for expeditions group as it is long and complicated. This is before the pipeline
#
# ## References
# * This is where the original creator got their sources from.
#
#
#
#
# _I have not manipulated this data in any way. only here for the creators reference._

# %%
import pandas as pd

# %%
root = "/Workspace/Repos/nikum.vedansh@gmail.com/himalayan-expeditions-project/references/refer_data/"
dictionary = pd.read_csv(root + 'himalayan_data_dictionary.csv')
references = pd.read_csv(root + 'refer.csv', encoding="latin1")

# %%
display(dictionary)

# %%
display(references)
