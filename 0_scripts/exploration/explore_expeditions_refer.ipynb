# %% [markdown]
# #EXPLORE - Expeditions - refer
# ####Find Data Quality Issues in:
# >_himalaya.bronze.expeditions_refer_
#
# ###Checks
# 0. Data Overview
# 1. Nulls
# 2. Duplicates
# 3. Distincts
# 4. Formats
# 5. Timeliness
# ___

# %% [markdown]
# > ##0. Data Overview

# %%
import pyspark.sql.functions as F
from datetime import date

# %%
df = spark.table("himalaya.bronze.expeditions_refer")

# %%
print(f"Rows: {df.count()}")
print(f"Columns: {len(df.columns)}")
display(df.limit(10))

# %% [markdown]
# > ## 1. Nulls
# - ####_Large Dataset_
#   - The data set is too large to make sense right now. I will figure out something later

# %%
for c in df.columns:
  null_count = df.filter(F.col(c).isNull()).count()
  status = "✅" if null_count == 0 else "❌"
  print(f"{status} Nulls in {c}: {null_count}")

# %%
for c in df.columns:
  null_count = df.filter(F.col(c).isNull()).count()
  if null_count != 0:
      print(f"{c}:")
      df.filter(F.col(c).isNull()).show()

# %% [markdown]
# > ## 2. Duplicates

# %%
total = df.count()
distinct = df.distinct().count()
duplicates = total - distinct

print(f"Total rows:    {total}")
print(f"Distinct rows: {distinct}")
print(f"Duplicates:    {duplicates}")

if duplicates == 0:
    print("✅ No duplicates")
else:
    print(f"❌ {duplicates} duplicate found")

# %% [markdown]
# > ## 3. Distinct
#
# - ####⚠️ Large Dataset Again
#   - Data does not seem to have any issues just large.

# %%
cat_cols = ["rtype", "rjrnl", "rlanguage"]

for c in cat_cols:
    distinct_count = df.select(c).distinct().count()
    print(f"{c}: {distinct_count} distinct values")

# %% [markdown]
# > ## 4. Format
#
# - ####✅ Looks fine

# %%
df.printSchema()

# %% [markdown]
# >## 5. Timeliness

# %%
min_date, max_date = df.select(F.min("ryear"), F.max("ryear")).first()

today = date.today()

print(f"Min: {min_date}")
print(f"Max: {max_date}")
print(f"Today: {today}")

print("✅ Max date is not in the future" if str(max_date) <= str(today) else "❌ Max date is in the future")

# %% [markdown]
# ___
# # Issues Found
# ### 1. Large Dataset
# - Will take care of it
#
# ### 2. Duplicates
# - ✅ No duplicates.
#
# ### 3. Distinct
# - looks fine
#
# ### 4. Format
# - ⚠️ `year` — stored as string. Will cast to DateType in Silver.
#
# ### 5. Timeliness
# - ⚠️ Various Cross Check Problems
