# %% [markdown]
# #Only for viewing tables from silver

# %%
display(spark.table("himalaya.silver.deaths").limit(5))

# %%
display(spark.table("himalaya.silver.expeditions_exped").limit(5))

# %%
display(spark.table("himalaya.silver.expeditions_members").limit(5))

# %%
display(spark.table("himalaya.silver.expeditions_peaks").limit(5))

# %%
display(spark.table("himalaya.silver.weather").limit(5))
