# %%
# config
S3_BUCKET = "himalaya-dp-vn"

DATASETS = [
    {
        "kaggle_id": "asaniczka/mountain-climbing-accidents-dataset",
        "file": "deaths_on_eight-thousanders.csv",
        "s3_key": "raw/deaths/",
        "encoding": "utf-8",
        "bronze_name": "himalaya.bronze.deaths"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "exped.csv",
        "s3_key": f"raw/expeditions/",
        "encoding": "utf-8",
        "bronze_name": "himalaya.bronze.expeditions_exped"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "members.csv",
        "s3_key": f"raw/expeditions/",
        "encoding": "utf-8",
        "bronze_name": "himalaya.bronze.expeditions_members"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "peaks.csv",
        "s3_key": f"raw/expeditions/",
        "encoding": "utf-8",
        "bronze_name": "himalaya.bronze.expeditions_peaks"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "refer.csv",
        "s3_key": f"raw/expeditions/",
        "encoding": "latin1",
        "bronze_name": "himalaya.bronze.expeditions_refer"
    }
]
