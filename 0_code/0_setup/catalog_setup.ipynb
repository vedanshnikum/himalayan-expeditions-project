# %%
# %sql

CREATE CATALOG IF NOT EXISTS himalaya;
USE CATALOG himalaya;

CREATE SCHEMA IF NOT EXISTS himalaya.bronze;
CREATE SCHEMA IF NOT EXISTS himalaya.silver;
CREATE SCHEMA IF NOT EXISTS himalaya.gold;
