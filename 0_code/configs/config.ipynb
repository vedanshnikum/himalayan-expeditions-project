# %%
# config
S3_BUCKET = "himalaya-dp-vn"

DATASETS = [
    {
        "kaggle_id": "asaniczka/mountain-climbing-accidents-dataset",
        "file": "deaths_on_eight-thousanders.csv",
        "s3_path": f"s3://{S3_BUCKET}/raw/deaths/",
        "encoding": "utf-8"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "exped.csv",
        "s3_path": f"s3://{S3_BUCKET}/raw/expeditions/",
        "encoding": "utf-8"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "members.csv",
        "s3_path": f"s3://{S3_BUCKET}/raw/expeditions/",
        "encoding": "utf-8"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "peaks.csv",
        "s3_path": f"s3://{S3_BUCKET}/raw/expeditions/",
        "encoding": "utf-8"
    },
    {
        "kaggle_id": "siddharth0935/himalayan-expeditions",
        "file": "refer.csv",
        "s3_path": f"s3://{S3_BUCKET}/raw/expeditions/",
        "encoding": "latin1"
    }
]
